# %%
import numpy as np
import MDAnalysis as mda
from MDAnalysis.analysis import align
from MDAnalysis.analysis.rms import RMSF
from MDAnalysis.analysis.rms import rmsd
from glob import glob
import itertools

# %%
def score_rmsd(rmsd_array, cutoff=5.0):
    
    # Find the largest number of well-aligned structures. Well-aligned means RMSD smaller than rmsd_cutoff
    well_aligned_ubs = (rmsd_array < cutoff).sum(axis=1)

    # Number of well aligned structures
    n = well_aligned_ubs.max()
    
    # Number of similarly well aligned structures
    filtered = rmsd_array[well_aligned_ubs == n]
    
    combined_rmsds = np.sqrt(np.square(filtered).sum(axis=1) / len(filtered[0]))
    best_id = np.argmin(combined_rmsds)

    return filtered[best_id]



def calc_rmsd(input_rec, remove_H=True, debug=False, write=True, ss_dist_cutoff=2.25):

    # Load reference structure
    u_ref = mda.Universe(input_rec["ref_PDB"])
    target_ref = u_ref.select_atoms(input_rec["ref_target"])

    # Load model structure
    model_names = glob(input_rec["model_PDBs"])
        #Remove H atoms in models
    if remove_H:
        new_model_names=[]
        for model_name in model_names:
            u_single_model = mda.Universe(
                        model_name,
                        in_memory = True,
                        )
            all_ha=u_single_model.select_atoms("not type H")
            output_model_name="/".join(model_name.split("/")[:-1])+"/noH_"+model_name.split("/")[-1]
            if debug:
                print(output_model_name)
            if output_model_name==model_name:
                raise Exception("Safeguard to not overwrite original model.")
            all_ha.write(output_model_name)
            new_model_names.append(output_model_name)
        model_names=list(new_model_names)
        #Actual loading
    u_model = mda.Universe(
              *model_names,
              all_coordinates = True,  # To use also the first frame.
              in_memory = True,
    )
    target_model = u_model.select_atoms(input_rec["model_target"])
    
    # Get reference and model ubiquitine atom groups.
    ub_refs = []
    ub_models = []
    for key in list(input_rec.keys()):
        if "ref_Ub" in key:
            ub_refs.append(u_ref.select_atoms(input_rec[key]))
        if "model_Ub" in key:
            ub_models.append(u_model.select_atoms(input_rec[key]))

    # Print summary of atom numbers and frames
    if debug:
        print (" Ref. Target: ", target_ref.n_atoms)
        print (" Mod. Target: ", target_model.n_atoms)
        for i,elem in enumerate(ub_refs):
            print (f" Ref. Ub{i}: ", elem.n_atoms)
        for i,elem in enumerate(ub_models):
            print (f" Mod. Ub{i}: ", elem.n_atoms)
        print (f" Found {u_ref.trajectory.n_frames} reference frames.")

    #
    # RMSD calculation startegy:
    #
    # for all models
    #   for all references
    #     align model target to ref target
    #     align model all to model target
    #     pick as RMSD_A the minimal one, RMSD_B as the second smallest, store the pair
    #   pick the pair with the best combined RMSD = sqrt( RMSD_A^2 / 2 + RMSD_B^2 /2)
    #
    
    if len(ub_models) <= len(ub_refs):
        permuted = list(itertools.permutations(ub_refs))
        permuted = list(set([ elem[:len(ub_models)] for elem in permuted ]))
        fixed = ub_models
    else:
        permuted = list(itertools.permutations(ub_models))
        permuted = list(set([ elem[:len(ub_refs)] for elem in permuted ]))
        fixed = ub_refs
    print (f" Can create {len(permuted)} unique assignments per reference frame.")
    
    # Store results
    all_target_rmsd = np.zeros(len(model_names))
    all_ub_rmsd     = np.zeros((len(model_names), 2))
    all_ub_bond     = np.zeros(len(model_names))
    
    for ts_model in u_model.trajectory:
        # CYS-CYS Bond formed?
        try:
            ss_dist = np.linalg.norm(u_model.select_atoms(input_rec["mdl_Ub1_CYS"]+" and name SG").positions-u_model.select_atoms(input_rec["mdl_Ub2_CYS"]+" and name SG").positions)
            if ss_dist_cutoff>=ss_dist:
                all_ub_bond[ts_model.frame] = 2 # = cys-bond
            else:
                all_ub_bond[ts_model.frame] = 1 # = cys-no-bond
        except:
            all_ub_bond[ts_model.frame] = 0 # = no-bond
        # Store all best-Ub-RMSD-pair for all reference combinations
        ub_rmsd_for_all_refs = np.zeros((u_ref.trajectory.n_frames, 2))

        for ts_ref in u_ref.trajectory:
            # Align target in model onto target in reference
            #  Step 1: Align target_model onto target_ref
            align.alignto(target_model, target_ref, select="all", match_atoms=False)
            #  Step 2: Align u_model onto target_model
            align.alignto(u_model, target_model, select=input_rec["model_target"], match_atoms=False)
            
            # Compute RMSDs
            #  Step 1: Target vs target
            target_rmsd = rmsd(target_model.positions, target_ref.positions, center=False, superposition=False)
            #  Step 2: Compare all model Ubs vs all ref Ubs. They can differ in their number

            ub_perm_rmsds = np.zeros((len(permuted), len(fixed)))
            for i, perm in enumerate(permuted):
                for j,fp in enumerate(zip(fixed,perm)):
                    f = fp[0]
                    p = fp[1]
                    # print (f.segids[0], "-", p.segids[0], end='   ')
                    ub_perm_rmsds[i,j] = rmsd(f.positions, p.positions, center=False, superposition=False)
            
            ub_rmsd_for_all_refs[ts_ref.frame] = score_rmsd(ub_perm_rmsds)
            
        # Determine minimal overall diUb RMSD for all the entries, and select the minimal.
        combined_rmsds = np.sqrt(np.square(ub_rmsd_for_all_refs).sum(axis=1) / 2)
        best_ref_id = np.argmin(combined_rmsds)
            
        all_target_rmsd[ts_model.frame] = target_rmsd
        all_ub_rmsd[ts_model.frame]     = ub_rmsd_for_all_refs[best_ref_id]

    u_model.select_atoms("not type H").atoms.write(f"{input_rec['aligned_model']}", frames='all') #not type H necessary to ensure same number of atoms for models with and without formed disulfide bond

    return model_names, all_target_rmsd, all_ub_rmsd, all_ub_bond

# %%
input_rec_dic={
  "5ymy":
      {
       "ref_PDB"      : "../04_Ref_structures/5ymy.pdb",
       "ref_target"   : "chainID C and name CA and resnum 19:132",
       "ref_Ub1"      : "chainID A and name CA",  # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA",  # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 19:132",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "aligned_model": "5ymy/aligned-5ymy.pdb",
      },
  "5ymy-bond":
      {"ref_PDB"      : "../04_Ref_structures/5ymy.pdb",
       "ref_target"   : "chainID C and name CA and resnum 19:132",
       "ref_Ub1"      : "chainID A and name CA",   # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA",   # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 19:132",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "5ymy-bond/aligned-5ymy-bond.pdb",
      },
  "6isu":
      {"ref_PDB"      : "../04_Ref_structures/6isu.pdb",
       "ref_target"   : "chainID A and name CA and resnum 4:230",
       "ref_Ub1"      : "chainID C and name CA",   # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA",   # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 4:230",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "aligned_model": "6isu/aligned-6isu.pdb",
      },
  "6isu-bond":
      {"ref_PDB"      : "../04_Ref_structures/6isu.pdb",
       "ref_target"   : "chainID A and name CA and resnum 4:230",
       "ref_Ub1"      : "chainID C and name CA",   # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA",   # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 4:230",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "6isu-bond/aligned-6isu-bond.pdb",
      },
  "6tuv":
      {"ref_PDB"      : "../04_Ref_structures/6tuv.pdb",
       "ref_target"   : "chainID A and name CA and resnum 110:369",
       "ref_Ub1"      : "chainID H and name CA and resnum 1:71",  # PROXIMAL
       "ref_Ub2"      : "chainID D and name CA and resnum 1:71",  # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 1:260",
       "model_Ub1"    : "chainID B and name CA and resnum 1:71",
       "model_Ub2"    : "chainID C and name CA and resnum 1:71",
       "aligned_model": "6tuv/aligned-6tuv.pdb",
      },
  "6tuv-bond":
      {"ref_PDB"      : "../04_Ref_structures/6tuv.pdb",
       "ref_target"   : "chainID A and name CA and resnum 110:369",
       "ref_Ub1"      : "chainID H and name CA and resnum 1:71",  # PROXIMAL
       "ref_Ub2"      : "chainID D and name CA and resnum 1:71",  # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 1:260",
       "model_Ub1"    : "chainID B and name CA and resnum 1:71",
       "model_Ub2"    : "chainID C and name CA and resnum 1:71",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "6tuv-bond/aligned-6tuv-bond.pdb",
      },
  "6ud0":
      {"ref_PDB"      : "../04_Ref_structures/6ud0.pdb",
       "ref_target"   : "chainID C and name CA and resnum 3:143",
       "ref_Ub1"      : "chainID B and name CA and resnum 1:76",  # PROXIMAL
       "ref_Ub2"      : "chainID A and name CA and resnum 1:76",  # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 3:143",
       "model_Ub1"    : "chainID B and name CA and resnum 1:76",
       "model_Ub2"    : "chainID C and name CA and resnum 1:76",
       "aligned_model": "6ud0/aligned-6ud0.pdb",
      },
  "6ud0-bond":
      {"ref_PDB"      : "../04_Ref_structures/6ud0.pdb",
       "ref_target"   : "chainID C and name CA and resnum 3:143",
       "ref_Ub1"      : "chainID A and name CA and resnum 1:76",  # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA and resnum 1:76",  # DISTAL
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 3:143",
       "model_Ub1"    : "chainID B and name CA and resnum 1:76",
       "model_Ub2"    : "chainID C and name CA and resnum 1:76",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "6ud0-bond/aligned-6ud0-bond.pdb",
      },
  "7keo":  # has two target chains!
      {"ref_PDB"      : "../04_Ref_structures/7keo.pdb",
       "ref_target"   : "(chainID E and resnum 5:229) or (chainID F and resnum 2:215) and name CA",
       "ref_Ub1"      : "chainID G and name CA and resnum 1:72",  # PROXIMAL
       "ref_Ub2"      : "chainID H and name CA and resnum 1:72",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "(chainID A and resnum 5:229) or (chainID B and resnum 2:215) and name CA",
       "model_Ub1"    : "chainID C and name CA and resnum 1:72", 
       "model_Ub2"    : "chainID D and name CA and resnum 1:72",
       "aligned_model": "7keo/aligned-7keo.pdb",
      },
  "7keo-bond":  # has two target chains!
      {"ref_PDB"      : "../04_Ref_structures/7keo.pdb",
       "ref_target"   : "(chainID E and resnum 5:229) or (chainID F and resnum 2:215) and name CA",
       "ref_Ub1"      : "chainID G and name CA and resnum 1:72",  # PROXIMAL
       "ref_Ub2"      : "chainID H and name CA and resnum 1:72",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "(chainID A and resnum 5:229) or (chainID B and resnum 2:215) and name CA",
       "model_Ub1"    : "chainID C and name CA and resnum 1:72",
       "model_Ub2"    : "chainID D and name CA and resnum 1:72",
       "mdl_Ub1_CYS"  : "chainID C and resname CYS",
       "mdl_Ub2_CYS"  : "chainID D and resname CYS",
       "aligned_model": "7keo-bond/aligned-7keo-bond.pdb",
      },
  "7m4n":
      {"ref_PDB"      : "../04_Ref_structures/7m4n.pdb",
       "ref_target"   : "chainID A and name CA and resnum 652:760",
       "ref_Ub1"      : "chainID E and name CA",   # PROXIMAL
       "ref_Ub2"      : "chainID C and name CA",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 4:112",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "aligned_model": "7m4n/aligned-7m4n.pdb",
      },
  "7m4n-bond":
      {"ref_PDB"      : "../04_Ref_structures/7m4n.pdb",
       "ref_target"   : "chainID A and name CA and resnum 652:760",
       "ref_Ub1"      : "chainID E and name CA",  # PROXIMAL
       "ref_Ub2"      : "chainID C and name CA",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 4:112",
       "model_Ub1"    : "chainID B and name CA",
       "model_Ub2"    : "chainID C and name CA and not (resnum 77 and resname CYS)",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "7m4n-bond/aligned-7m4n-bond.pdb",
      },
  "7uv5":
      {"ref_PDB"      : "../04_Ref_structures/7uv5.pdb",
       "ref_target"   : "chainID A and resnum 4:315 and name CA and not altLoc B",
       "ref_Ub1"      : "chainID B and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",  # PROXIMAL
       "ref_Ub2"      : "chainID C and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/R1AB-1564-1878_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and resnum 4:315 and name CA and not altLoc B",
       "model_Ub1"    : "chainID B and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "model_Ub2"    : "chainID C and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "aligned_model": "7uv5/aligned-7uv5.pdb",
      },
  "7uv5-bond":
      {"ref_PDB"      : "../04_Ref_structures/7uv5.pdb",
       "ref_target"   : "chainID A and resnum 4:315 and name CA and not altLoc B",
       "ref_Ub1"      : "chainID B and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",  # PROXIMAL
       "ref_Ub2"      : "chainID C and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/R1AB-1564-1878_and_UBQ_K48C_and_UBQ_77C/ranked_*.pdb", #Unrelaxed, hence different chain numberings
       "model_target" : "chainID B and resnum 4:315 and name CA and not altLoc B",
       "model_Ub1"    : "chainID C and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "model_Ub2"    : "chainID D and (resnum 1:2 or resnum 7:11 or resnum 17:19 or resnum 23:29 or resnum 35:50 or resnum 66:73) and name CA",
       "mdl_Ub1_CYS"  : "chainID C and resname CYS",
       "mdl_Ub2_CYS"  : "chainID D and resname CYS",
       "aligned_model": "7uv5-bond/aligned-7uv5-bond.pdb",
      },
  "7uyh":
      {"ref_PDB"      : "../04_Ref_structures/7uyh.pdb",
       "ref_target"   : "chainID A and name CA and resnum 1:276",
       "ref_Ub1"      : "chainID C and name CA and resnum 1:75",  # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA and resnum 1:75",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 1:276",
       "model_Ub1"    : "chainID B and name CA and resnum 1:75",
       "model_Ub2"    : "chainID C and name CA and resnum 1:75",
       "aligned_model": "7uyh/aligned-7uyh.pdb",
      },
  "7uyh-bond":
      {"ref_PDB"      : "../04_Ref_structures/7uyh.pdb",
       "ref_target"   : "chainID A and name CA and resnum 1:276",
       "ref_Ub1"      : "chainID C and name CA and resnum 1:75",  # PROXIMAL
       "ref_Ub2"      : "chainID B and name CA and resnum 1:75",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 1:276",
       "model_Ub1"    : "chainID B and name CA and resnum 1:75",
       "model_Ub2"    : "chainID C and name CA and resnum 1:75",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "7uyh-bond/aligned-7uyh-bond.pdb",
      },
  "8c61":
      {"ref_PDB"      : "../04_Ref_structures/8c61.pdb",
       "ref_target"   : "chainID A and name CA and resnum 29:198 206:358",
       "ref_Ub1"      : "chainID B and name CA and resnum 1:75",  # PROXIMAL
       "ref_Ub2"      : "chainID C and name CA and resnum 1:75",
       "ref_Ub3"      : "chainID F and name CA and resnum 1:75",
       "ref_Ub4"      : "chainID I and name CA and resnum 1:75",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/USP54-21-369_and_UBQ_and_UBQ/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 9:178 186:338",
       "model_Ub1"    : "chainID B and name CA and resnum 1:75",
       "model_Ub2"    : "chainID C and name CA and resnum 1:75",
       "aligned_model": "8c61/aligned-8c61.pdb",
      },
  "8c61-bond":
      {"ref_PDB"      : "../04_Ref_structures/8c61.pdb",
       "ref_target"   : "chainID A and name CA and resnum 29:198 206:358",
       "ref_Ub1"      : "chainID B and name CA and resnum 1:75",  # PROXIMAL
       "ref_Ub2"      : "chainID C and name CA and resnum 1:75",
       "ref_Ub3"      : "chainID F and name CA and resnum 1:75",
       "ref_Ub4"      : "chainID I and name CA and resnum 1:75",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/USP54-21-369_and_UBQ_K63C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 9:178 186:338",
       "model_Ub1"    : "chainID B and name CA and resnum 1:75",
       "model_Ub2"    : "chainID C and name CA and resnum 1:75",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "8c61-bond/aligned-8c61-bond.pdb",
      },
  "9avt":
      {"ref_PDB"      : "../04_Ref_structures/9avt.pdb",
       "ref_target"   : "chainID C and name CA and resnum 664:693 and not altLoc B",
       "ref_Ub1"      : "chainID B and name CA and resnum 1:73    and not altLoc B",   # PROXIMAL
       "ref_Ub2"      : "chainID A and name CA and resnum 1:73    and not altLoc B",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/ranked_*.pdb", 
       "model_target" : "chainID B and name CA and resnum 1:30    and not altLoc B", #Unrelaxed, hence different chain numberings
       "model_Ub1"    : "chainID C and name CA and resnum 1:73    and not altLoc B",
       "model_Ub2"    : "chainID D and name CA and resnum 1:73    and not altLoc B",
       "aligned_model": "9avt/aligned-9avt.pdb",
      },
  "9avt-bond":
      {"ref_PDB"      : "../04_Ref_structures/9avt.pdb",
       "ref_target"   : "chainID C and name CA and resnum 664:693 and not altLoc B",
       "ref_Ub1"      : "chainID B and name CA and resnum 1:73    and not altLoc B",  # PROXIMAL
       "ref_Ub2"      : "chainID A and name CA and resnum 1:73    and not altLoc B",
       "model_PDBs"   : "../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/ranked_*.pdb",
       "model_target" : "chainID A and name CA and resnum 1:30    and not altLoc B",
       "model_Ub1"    : "chainID B and name CA and resnum 1:73    and not altLoc B",
       "model_Ub2"    : "chainID C and name CA and resnum 1:73    and not altLoc B",
       "mdl_Ub1_CYS"  : "chainID B and resname CYS",
       "mdl_Ub2_CYS"  : "chainID C and resname CYS",
       "aligned_model": "9avt-bond/aligned-9avt-bond.pdb",
    },
}

# %%
# Compute RMSDs

result_target_dict = {}
result_diub_dict = {}
result_monoub_dict = {}
result_ub_bond_dict = {}
result_ub_bond_dict_dup = {}
for system in input_rec_dic.keys():
#for system in ["5ymy", "5ymy-bond"]:
    print (system)
    #Exclude special cases which will be treated seperately
    if system in ["7uv5", "7uv5-bond", "8c61", "8c61-bond"]:
        continue
    model_names, target_rmsd, ub_rmsd, ub_bond = calc_rmsd(input_rec=input_rec_dic[system], debug = True)
    result_target_dict[system] = target_rmsd
    # USE IF THE UB RMSD-S ARE COMBINED
    result_diub_dict[system] = np.sqrt(ub_rmsd[:,0]**2 + ub_rmsd[:,1]**2) / np.sqrt(2)
    result_monoub_dict[system+"-proximal"] = ub_rmsd[:,0]
    result_monoub_dict[system+"-distal"]   = ub_rmsd[:,1]
    result_ub_bond_dict[system] = ub_bond
    result_ub_bond_dict_dup[system] = np.append(ub_bond, ub_bond)
    print ()
# Out:
# 5ymy
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_24.pdb
# /home/tb/jastuke/conda-envs/LC3-LIR-analysis/lib/python3.10/site-packages/MDAnalysis/core/universe.py:641: UserWarning: Reader has no dt information, set to 1.0 ps
#   dt=self.trajectory.ts.dt * step,
# /home/tb/jastuke/conda-envs/LC3-LIR-analysis/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:753: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# /home/tb/jastuke/conda-envs/LC3-LIR-analysis/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_and_UBQ/noH_ranked_22.pdb
# /home/tb/jastuke/conda-envs/LC3-LIR-analysis/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:432: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# /home/tb/jastuke/conda-envs/LC3-LIR-analysis/lib/python3.10/site-packages/MDAnalysis/coordinates/base.py:718: UserWarning: Reader has no dt information, set to 1.0 ps
#   return self.ts.dt
#  Ref. Target:  114
#  Mod. Target:  114
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 20 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 5ymy-bond
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/ADRM1-1-150_and_UBQ_K48C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  114
#  Mod. Target:  114
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 20 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6isu
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  227
#  Mod. Target:  227
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6isu-bond
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/UCHL3_and_UBQ_K27C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  227
#  Mod. Target:  227
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6tuv
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  260
#  Mod. Target:  260
#  Ref. Ub0:  71
#  Ref. Ub1:  71
#  Mod. Ub0:  71
#  Mod. Ub1:  71
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6tuv-bond
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/Mindy1-110-384_and_UBQ_K48C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  260
#  Mod. Target:  260
#  Ref. Ub0:  71
#  Ref. Ub1:  71
#  Mod. Ub0:  71
#  Mod. Ub1:  71
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6ud0
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  141
#  Mod. Target:  141
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 20 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 6ud0-bond
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/Tsg101-1-145_and_UBQ_K63C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  141
#  Mod. Target:  141
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 20 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7keo
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  439
#  Mod. Target:  439
#  Ref. Ub0:  72
#  Ref. Ub1:  72
#  Mod. Ub0:  72
#  Mod. Ub1:  72
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7keo-bond
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/7KEO-chain-1_and_7KEO-chain-2_and_UBQ_K29C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  439
#  Mod. Target:  439
#  Ref. Ub0:  72
#  Ref. Ub1:  72
#  Mod. Ub0:  72
#  Mod. Ub1:  72
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7m4n
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  109
#  Mod. Target:  109
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7m4n-bond
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/RNF216-649-784_and_UBQ_K63C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  109
#  Mod. Target:  109
#  Ref. Ub0:  76
#  Ref. Ub1:  76
#  Mod. Ub0:  76
#  Mod. Ub1:  76
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7uv5
# 7uv5-bond
# 7uyh
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  276
#  Mod. Target:  276
#  Ref. Ub0:  75
#  Ref. Ub1:  75
#  Mod. Ub0:  75
#  Mod. Ub1:  75
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 7uyh-bond
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/LotA-1-276_and_UBQ_K6C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  276
#  Mod. Target:  276
#  Ref. Ub0:  75
#  Ref. Ub1:  75
#  Mod. Ub0:  75
#  Mod. Ub1:  75
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 8c61
# 8c61-bond
# 9avt
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_and_UBQ/noH_ranked_22.pdb
#  Ref. Target:  30
#  Mod. Target:  30
#  Ref. Ub0:  73
#  Ref. Ub1:  73
#  Mod. Ub0:  73
#  Mod. Ub1:  73
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.
#
# 9avt-bond
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_14.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_24.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_20.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_17.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_8.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_3.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_4.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_9.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_10.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_12.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_13.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_6.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_19.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_16.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_23.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_2.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_21.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_0.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_18.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_7.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_15.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_5.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_1.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_11.pdb
# ../03_AF2.3/alphapulldown_output/TAB2-664-693_and_UBQ_K6C_and_UBQ_77C/noH_ranked_22.pdb
#  Ref. Target:  30
#  Mod. Target:  30
#  Ref. Ub0:  73
#  Ref. Ub1:  73
#  Mod. Ub0:  73
#  Mod. Ub1:  73
#  Found 1 reference frames.
#  Can create 2 unique assignments per reference frame.

# %%
# Transfrom the AF3 model data to pandas DataFrame suitable for seaborn plotting

import pandas as pd

ub_bond_df = pd.DataFrame (result_ub_bond_dict)
ub_bond_df = ub_bond_df.melt(var_name='PDB', value_name='bond')

ub_bond_dup_df = pd.DataFrame (result_ub_bond_dict_dup)
ub_bond_dup_df = ub_bond_dup_df.melt(var_name='PDB', value_name='bond')

target_rmsd_df = pd.DataFrame (result_target_dict)
target_rmsd_df = target_rmsd_df.melt(var_name='PDB', value_name='RMSD')
target_rmsd_df['bond'] = ub_bond_df['bond'].apply(lambda x: 'cys (bond)' if x==2 else 'cys (no bond)' if x==1 else "no bond")
#target_rmsd_df['bond'] = target_rmsd_df['PDB'].apply(lambda x: 'no' if 'bond' not in x else 'cys (yes)' if else "cys (no)")
target_rmsd_df['PDB']  = target_rmsd_df['PDB'].str.replace('-bond', '', regex=True)

diub_rmsd_df = pd.DataFrame (result_diub_dict)
diub_rmsd_df = diub_rmsd_df.melt(var_name='PDB', value_name='RMSD')
diub_rmsd_df['bond'] = ub_bond_df['bond'].apply(lambda x: 'cys (bond)' if x==2 else 'cys (no bond)' if x==1 else "no bond")
diub_rmsd_df['PDB']  = diub_rmsd_df['PDB'].str.replace('-bond', '', regex=True)

monoub_rmsd_df = pd.DataFrame (result_monoub_dict)
monoub_rmsd_df = monoub_rmsd_df.melt(var_name='PDB', value_name='RMSD')
monoub_rmsd_df['bond'] = ub_bond_dup_df['bond'].apply(lambda x: 'cys (bond)' if x==2 else 'cys (no bond)' if x==1 else "no bond")
monoub_rmsd_df['PDB']  = monoub_rmsd_df['PDB'].str.replace('-bond', '', regex=True)
monoub_rmsd_df['proximal'] = monoub_rmsd_df['PDB'].apply(lambda x: 'yes' if 'proximal' in x else 'no')
monoub_rmsd_df['PDB']  = monoub_rmsd_df['PDB'].str.replace('-proximal', '', regex=True)
monoub_rmsd_df['PDB']  = monoub_rmsd_df['PDB'].str.replace('-distal', '', regex=True)

for i in monoub_rmsd_df['bond']:
    print(i)
# Out:
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# no bond
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (no bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)
# cys (bond)
# cys (bond)
# cys (bond)
# cys (no bond)

# %%
# # Plot the distances

# import matplotlib.pyplot as plt
# from matplotlib.gridspec import GridSpec
# import seaborn
# plt.rcParams['svg.fonttype'] = 'none'

# # Get the default color palette
# colors = seaborn.color_palette()

# fig = plt.figure(layout="constrained")
 
# # use to set style of background of plot
# seaborn.set_theme(rc={'figure.figsize':(11.7,8.27)})
# seaborn.set(style="whitegrid")


# ax = seaborn.boxplot(x="PDB", y="RMSD", hue="bond", data=target_rmsd_df)
# ax.set_ylabel(r'Target RMSD [$\AA$]')
# ax.legend(title='Using bond?', labels=['No', 'Yes'])
# leg = ax.get_legend()
# leg.legendHandles[0].set_facecolor(colors[0])
# leg.legendHandles[1].set_facecolor(colors[1])
# leg.legendHandles[0].set_linewidth(1)
# leg.legendHandles[1].set_linewidth(1)


# plt.savefig("AF3-target-rmsd.svg", bbox_inches=0, transparent=True)
# plt.savefig("AF3-target-rmsd.png", bbox_inches=0, transparent=False)

# plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn
plt.rcParams['svg.fonttype'] = 'none'
# Get the default color palette
colors = seaborn.color_palette()
colors = [i for index, i in enumerate(colors) if index not in [2]]  #Slightly more color-blind friendly

fig = plt.figure(layout="constrained")
 
# use to set style of background of plot
seaborn.set_theme(rc={'figure.figsize':(11.7,8.27)})
seaborn.set(style="whitegrid")


ax = seaborn.boxplot(x="PDB", y="RMSD", hue="bond", hue_order=["no bond", "cys (no bond)", "cys (bond)"], data=diub_rmsd_df, palette=colors)
ax.set_ylabel(r'Diubiquitine RMSD [$\AA$]')
#ax.legend(title='Using bond?', labels=['No', 'Yes'])
ax.set_ylim([0,60])
ax.legend(title=None)
leg = ax.get_legend()
leg.legendHandles[0].set_facecolor(colors[0])
leg.legendHandles[1].set_facecolor(colors[1])
leg.legendHandles[2].set_facecolor(colors[2])
leg.legendHandles[0].set_linewidth(1)
leg.legendHandles[1].set_linewidth(1)
leg.legendHandles[2].set_linewidth(1)



limits = ax.get_xlim()
print (limits)
ax.axvspan(-0.5, 0.5, color='gray', alpha=0.2)
ax.axvspan( 1.5, 2.5, color='gray', alpha=0.2)
ax.axvspan( 3.5, 4.5, color='gray', alpha=0.2)
ax.axvspan( 5.5, 6.5, color='gray', alpha=0.2)
ax.axvspan( 7.5, 8.5, color='gray', alpha=0.2)
ax.set_xlim(limits)
#plt.plot([6], [50], marker=r'$*$', markersize=20, color="black")
#plt.plot([8], [50], marker=r'$*$', markersize=20, color="black")
plt.savefig("AF2.3-diub-rmsd.svg", bbox_inches=0, transparent=True)
plt.savefig("AF2.3-diub-rmsd.png", bbox_inches=0, transparent=False)
plt.show()
# Out:
# (-0.5, 7.5)
# /tmp/ipykernel_5889/3323475277.py:22: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_facecolor(colors[0])
# /tmp/ipykernel_5889/3323475277.py:23: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[1].set_facecolor(colors[1])
# /tmp/ipykernel_5889/3323475277.py:24: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[2].set_facecolor(colors[2])
# /tmp/ipykernel_5889/3323475277.py:25: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_linewidth(1)
# /tmp/ipykernel_5889/3323475277.py:26: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[1].set_linewidth(1)
# /tmp/ipykernel_5889/3323475277.py:27: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[2].set_linewidth(1)

# %%
# # Get the default color palette
# colors = seaborn.color_palette()

# fig = plt.figure(layout="constrained")
 
# # use to set style of background of plot
# seaborn.set_theme(rc={'figure.figsize':(11.7,8.27)})
# seaborn.set(style="whitegrid")


# ax = seaborn.boxplot(x="PDB", y="RMSD", hue="proximal", data=monoub_rmsd_df[monoub_rmsd_df['bond'] == 'no'])
# ax.set_ylabel(r'Ubiquitine RMSD [$\AA$]')
# #ax.legend(title='Using bond?', labels=['No', 'Yes'])
# ax.set_ylim([0,80])


# plt.savefig("AF3-monoub-rmsd.svg", bbox_inches=0, transparent=True)
# plt.savefig("AF3-monoub-rmsd.png", bbox_inches=0, transparent=False)

# plt.show()

# %%
# # Get the default color palette
# colors = seaborn.color_palette()

# fig = plt.figure(layout="constrained")
 
# # use to set style of background of plot
# seaborn.set_theme(rc={'figure.figsize':(11.7,8.27)})
# seaborn.set(style="whitegrid")


# ax = seaborn.boxplot(x="PDB", y="RMSD", hue="proximal", data=monoub_rmsd_df[monoub_rmsd_df['bond'] == 'yes'])
# ax.set_ylabel(r'Ubiquitine RMSD [$\AA$]')
# #ax.legend(title='Using bond?', labels=['No', 'Yes'])
# ax.set_ylim([0,80])


# plt.savefig("AF3-monoub-bond-rmsd.svg", bbox_inches=0, transparent=True)
# plt.savefig("AF3-monoub-bond-rmsd.png", bbox_inches=0, transparent=False)

# plt.show()

# %%
# use to set style of background of plot
seaborn.set_theme(rc={'figure.figsize':(11.7,8.27)})
seaborn.set(style="whitegrid")

# Get the default color palette
colors = seaborn.color_palette()
colors = [i for index, i in enumerate(colors) if index not in [2]]  #Slightly more color-blind friendly

#pdb_names = '5ymy','6isu','6tuv','6ud0','7keo','7m4n','7uv5','7uyh','8c61','9avt'
#protein_names = 'ADRM1', 'UHCL3', 'Mindy1', 'Tsg101', 'sAB-K29', 'RNF216', 'R1AB', 'LotA', 'USP54', 'TAB2'
#Remove special cases:
pdb_names = '5ymy','6isu','6tuv','6ud0','7keo','7m4n','7uyh','9avt'
protein_names = 'ADRM1', 'UHCL3', 'Mindy1', 'Tsg101', 'sAB-K29', 'RNF216', 'LotA', 'TAB2'

fig = plt.figure(layout="constrained", figsize=(10,20))
gs = GridSpec(5, 6, figure=fig, wspace=0.2, hspace=0.05)

cnt = 0

for pdb, protein in zip(pdb_names, protein_names):

    # Get column and row from cnt
    row = int(cnt/2)
    col = (cnt % 2) * 3
    
    ax1 = fig.add_subplot(gs[row, col])
    ax2 = fig.add_subplot(gs[row, col+1:col+3])
    ax2.set_title(f"PDB:{pdb}", x=0.1, y=1.05)

    seaborn.boxplot(x="PDB", y="RMSD", hue="bond", hue_order=["no bond", "cys (no bond)", "cys (bond)"], data=target_rmsd_df[target_rmsd_df['PDB'] == pdb], ax=ax1, width=0.5, linewidth=0.7, palette=colors)
    ax1.set_ylabel(r'Target RMSD [$\AA$]')
    ax1.set_xticklabels([protein,])
    ax1.set_ylim([0,6]) 
    ax1.set_xlabel(None)
    legend = ax1.legend()
    legend.remove()
    
    

    data = monoub_rmsd_df[monoub_rmsd_df['PDB'] == pdb]
    seaborn.boxplot(x="proximal", y="RMSD", hue="bond", hue_order=["no bond", "cys (no bond)", "cys (bond)"], data=data, ax=ax2, width=0.5, linewidth=0.7, palette=colors)
    ax2.set_ylabel(r'Ub RMSD [$\AA$]')
    ax2.set_xticklabels([r"Ub-1", r"Ub-2"])
    if cnt==0:
        ax2.legend(title=None)
        leg = ax2.get_legend()
        leg.legendHandles[0].set_facecolor(colors[0])
        leg.legendHandles[1].set_facecolor(colors[1])
        leg.legendHandles[2].set_facecolor(colors[2])
        leg.legendHandles[0].set_linewidth(1)
        leg.legendHandles[1].set_linewidth(1)
        leg.legendHandles[2].set_linewidth(1)
    else:
        legend = ax2.legend()
        legend.remove()
        
    ax2.set_xlabel(None)
    ax2.set_ylim([0,80])
    
    cnt += 1

plt.savefig(f"AF2.3-si-panel.svg", bbox_inches=0, transparent=True)
plt.savefig(f"AF2.3-si-panel.png", bbox_inches=0, transparent=False)
plt.show()
# Out:
# /tmp/ipykernel_5889/896427512.py:47: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_facecolor(colors[0])
# /tmp/ipykernel_5889/896427512.py:48: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[1].set_facecolor(colors[1])
# /tmp/ipykernel_5889/896427512.py:49: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[2].set_facecolor(colors[2])
# /tmp/ipykernel_5889/896427512.py:50: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_linewidth(1)
# /tmp/ipykernel_5889/896427512.py:51: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[1].set_linewidth(1)
# /tmp/ipykernel_5889/896427512.py:52: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[2].set_linewidth(1)
